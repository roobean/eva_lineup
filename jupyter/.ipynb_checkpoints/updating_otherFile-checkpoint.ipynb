# %%
import pandas as pd
from datetime import datetime, time, date
import numpy as np

# %%
df = pd.read_csv("../outputs_v2/05_grouping_2.csv")

# %%
sel= df[(df['subject_nr']==1)&(df['condition'] == 'live')]
# Out:
#    confidence_immediate           datetime         experiment_file  \
# 39                   no  11/04/17 10:27:22  lineup_liveWOMEN.osexp
# 40                   no  11/04/17 10:27:22  lineup_liveWOMEN.osexp
# 41                   no  11/04/17 10:27:22  lineup_liveWOMEN.osexp
# 42                   no  11/04/17 10:27:22  lineup_liveWOMEN.osexp
# 43                   no  11/04/17 10:27:22  lineup_liveWOMEN.osexp
# 44                   no  11/04/17 10:27:22  lineup_liveWOMEN.osexp
# 45                   no  11/04/17 10:27:22  lineup_liveWOMEN.osexp
# 46                   no  11/04/17 10:27:22  lineup_liveWOMEN.osexp
# 47                   no  11/04/17 11:05:18    lineup_liveMEN.osexp
# 48                   no  11/04/17 11:05:18    lineup_liveMEN.osexp
# 49                   50  11/04/17 11:05:18    lineup_liveMEN.osexp
# 50                   no  11/04/17 11:05:18    lineup_liveMEN.osexp
# 51                   no  11/04/17 11:05:18    lineup_liveMEN.osexp
# ...
